# %% [markdown]
# Mounts Gdrive and Git

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/drive'

# %%
# %ls
# Out:
# MyDrive/  Othercomputers/

# %%
# %cd 'MyDrive'
# Out:
# /content/drive/MyDrive

# %%
# %ls
# Out:
# MyDrive/  Othercomputers/

# %%
# %cd 'Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
# 「GPT_3_Dash_Playground.ipynb」的副本  「mountGit.ipynb」的副本  Untitled
# gpt3sharing/                           test/

# %%
# %cd gpt3sharing
# Out:
# /content/drive/MyDrive/Colab Notebooks/gpt3sharing

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
%

# %%
# !git checkout master
# Out:
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git add .

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/Colab Notebooks/test' 
# replace with your Github username 
GIT_USERNAME = "AriesyuGTH" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "gpt3sharing" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/Colab Notebooks/test
# GIT_PATH:  https://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@github.com/AriesyuGTH/gpt3sharing.git

# %%
# %cd test
# %cd "/content/drive/MyDrive/Colab Notebooks/test"    # Change directory to the location defined in project_path
# !git clone "https://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@github.com/AriesyuGTH/gpt3sharing.git" # clone the github repository
# Out:
# Cloning into 'gpt3sharing'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 2), reused 7 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), 12.40 KiB | 79.00 KiB/s, done.

# %%
# %cd gpt3sharing
# Out:
# /content/drive/MyDrive/Colab Notebooks/test/gpt3sharing

# %%
# %ls
# Out:
# GPT_3_Dash_Playground.ipynb  Readme.md
